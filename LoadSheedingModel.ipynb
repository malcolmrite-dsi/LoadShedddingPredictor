# %% [markdown]
# <a href="https://colab.research.google.com/github/malcolmrite-dsi/LoadShedddingPredictor/blob/main/LoadSheedingModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

# %%
train_data = pd.read_csv("drive/MyDrive/LockDown_Tracking.csv")

# %%
train_data.head()
# Out:
#   Date Time Hour Beginning  ...  Zero Line
# 0         2020-03-23 00:00  ...        0.0
# 1         2020-03-23 01:00  ...        0.0
# 2         2020-03-23 02:00  ...        0.0
# 3         2020-03-23 03:00  ...        0.0
# 4         2020-03-23 04:00  ...        0.0
#
# [5 rows x 11 columns]

# %%
train_data.tail(20)
# Out:
#      Date Time Hour Beginning  ...  Zero Line
# 8956         2021-03-31 04:00  ...        0.0
# 8957         2021-03-31 05:00  ...        0.0
# 8958         2021-03-31 06:00  ...        0.0
# 8959         2021-03-31 07:00  ...        0.0
# 8960         2021-03-31 08:00  ...        0.0
# 8961         2021-03-31 09:00  ...        0.0
# 8962         2021-03-31 10:00  ...        0.0
# 8963         2021-03-31 11:00  ...        0.0
# 8964         2021-03-31 12:00  ...        0.0
# 8965         2021-03-31 13:00  ...        0.0
# 8966         2021-03-31 14:00  ...        0.0
# 8967         2021-03-31 15:00  ...        0.0
# 8968         2021-03-31 16:00  ...        0.0
# 8969         2021-03-31 17:00  ...        0.0
# 8970         2021-03-31 18:00  ...        0.0
# 8971         2021-03-31 19:00  ...        0.0
# 8972         2021-03-31 20:00  ...        0.0
# 8973         2021-03-31 21:00  ...        0.0
# 8974         2021-03-31 22:00  ...        0.0
# ...

# %%
train_graph = train_data
train_graph["Date Time Hour Beginning"] = dt.datetime(train_graph["Date Time Hour Beginning"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-5ec05c4f685f> in <module>()
#       1 train_graph = train_data
# ----> 2 train_graph["Date Time Hour Beginning"] = dt.datetime(train_graph["Date Time Hour Beginning"])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in wrapper(self)
#     127         if len(self) == 1:
#     128             return converter(self.iloc[0])
# --> 129         raise TypeError(f"cannot convert the series to {converter}")
#     130
#     131     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>

# %%
train_data.describe()
# Out:
#        Original Res Forecast before Lockdown  ...  Zero Line
# count                            8904.000000  ...     8976.0
# mean                            25136.921452  ...        0.0
# std                              2753.072225  ...        0.0
# min                             18605.968000  ...        0.0
# 25%                             22733.241250  ...        0.0
# 50%                             25563.764000  ...        0.0
# 75%                             27002.109750  ...        0.0
# max                             33757.374000  ...        0.0
#
# [8 rows x 10 columns]

# %%
plt.plot(train_data["Date Time Hour Beginning"], train_data["Latest Official Residual Forecast"])
plt.show()
